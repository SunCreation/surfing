# %% [markdown]
# # 회계 정리 편하게 하기
# ## 1.

# %%
from chromedriver_autoinstaller import install
from selenium import webdriver
install()
driver = webdriver.Chrome()

# %%
driver.get('https://obank.kbstar.com/quics?page=C059223#CP')

# %%
html = driver.page_source

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(html,'html.parser')

# %%
soup
# Out:
# <html class="linux chrome chrome1 webkit webkit5" lang="ko" xml:lang="ko" xmlns="http://www.w3.org/1999/xhtml"><head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <script async="" charset="utf-8" defer="" src="/obank/js/container_obank.js?202205311807" type="text/javascript"></script><script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript"></script><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-TGSH3RL"></script><script type="text/javascript">
# var q_browserNavi =" ( 개인뱅킹 | 조회 | 계좌조회 | 통합ID 계좌조회 )";
# </script>
# <title>통합ID 계좌조회 - 간편조회 ( 개인뱅킹 | 조회 | 계좌조회 | 통합ID 계좌조회 )</title><meta content="telephone=no" name="format-detection"/>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# ...

# %%
import pandas as pd

# %%
source = driver.page_source
soup = BeautifulSoup(source, 'html.parser')
soup.find_all('table')[0]
# Out:
# <table class="tType02 ui-row2" summary="조회조건 설정(계좌번호, 조회기간 등)">
# <caption>조회조건 설정</caption>
# <colgroup><col width="18%"/><col/></colgroup>
# <tbody>
# <tr>
# <th scope="row">월별조회</th>
# <td>
# <div class="selPeriod">
# <select class="selbox" id="fromYear" name="fromYear" onchange="Rst_displayDay(this)" title="조회년도 선택">
# <option value="2003">2003</option>
# <option value="2004">2004</option>
# <option value="2005">2005</option>
# <option value="2006">2006</option>
# <option value="2007">2007</option>
# <option value="2008">2008</option>
# <option value="2009">2009</option>
# <option value="2010">2010</option>
# <option value="2011">2011</option>
# <option value="2012">2012</option>
# <option value="2013">2013</option>
# <option value="2014">2014</option>
# <option value="2015">2015</option>
# <option value="2016">2016</option>
# <option value="2017">2017</option>
# <option value="2018">2018</option>
# <option value="2019">2019</option>
# <option value="2020">2020</option>
# ...

# %%
def get_table():
    source = driver.page_source
    soup = BeautifulSoup(source, 'html.parser')
    
    return pd.read_html(str(soup.find_all('table')[1]))[0]

# %%
table1 = get_table()

# %%
table2 = get_table()

# %%
table3 = get_table()

# %%
table4 = get_table()

# %%
table5 = get_table()

# %%
table6 = get_table()

# %% [markdown]
# ![hi](https://cdn.discordapp.com/attachments/963369502005927986/981140681227640862/unknown.png)

# %%
table7 = get_table()

# %%
table8 = get_table()

# %%
talbe9 = get_table()

# %%
table9 = talbe9

# %%
table = pd.DataFrame()
for i in range(1,10):
    table = pd.concat([table,eval(f'table{i}')],axis=0)
table
# Out:
#                    거래일시     적요    보낸분/받는분  출금액(원)  입금액(원)   잔액(원) 송금메모   거래점
# 0   2022.05.31 13:49:52   체크카드       당산가든   16000       0  397327  NaN  KB카드
# 1   2022.05.28 19:21:02   체크카드     장수한우곱창   52000       0  413327  NaN  KB카드
# 2   2022.05.21 15:59:49   체크카드  주식회사서우리테일   79670       0  465327  NaN  KB카드
# 3   2022.05.21 14:31:24   체크카드  트레이더스스타필드  221550       0  544997  NaN  KB카드
# 4   2022.05.20 19:56:49   체크카드    스타벅스코리아   16600       0  766547  NaN  KB카드
# ..                  ...    ...        ...     ...     ...     ...  ...   ...
# 2   2021.12.19 14:45:17  FBS입금        이담은       0   50000  100000  NaN   기업2
# 3   2021.12.19 14:45:01   전자금융        이신영       0   10000   50000  NaN    카뱅
# 4   2021.12.19 14:44:57  FBS입금        안예성       0   10000   40000  NaN   기업2
# 5   2021.12.19 14:44:50   전자금융        박은진       0   30000   30000  NaN    카뱅
# 6   2021.12.13 14:55:59     신규        NaN       0       0       0  NaN    당진
#
# [167 rows x 8 columns]

# %%
table.to_csv('hi.csv',index=False)
